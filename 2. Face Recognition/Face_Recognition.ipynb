# %%
# Mounting GDRIVE
from google.colab import drive 
drive.mount('/mntDrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /mntDrive

# %%
#Import required packages
import os
import cv2
import glob
import dlib
from cv2 import resize
import numpy as np 
from numpy import expand_dims
from matplotlib import pyplot as plt
from matplotlib.patches import Rectangle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import ZeroPadding2D,Convolution2D,MaxPooling2D
from tensorflow.keras.layers import Dense,Dropout,Softmax,Flatten,Activation,BatchNormalization
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import tensorflow.keras.backend as K

# %%
path='/mntDrive/My Drive/Face_Recognition'
# Get Image names stored in "Images" folder
image_path_names=[]
person_names=set()
for file_name in glob.glob(path+'/Images/*_[1-9]*.png'):
  image_path_names.append(file_name)
  person_names.add(image_path_names[-1].split('/')[-1].split('_')[0])

# %%
person_names
# Out:
# {'aravindh', 'kasthuri', 'puja'}

# %%
os.mkdir(path+'/Test_Images_crop/')

# %%
# Create Separate folder for each person in "Test_Images_crop" folder
for person in person_names:
  os.mkdir(path+'/Test_Images_crop/'+person+'/')

# %%
# Detect face,crop face and save in corresponding folder
for file_name in test_image_path_names:
  img=cv2.imread(file_name)
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  rects=dnnFaceDetector(gray,1)
  left,top,right,bottom=0,0,0,0
  for (i,rect) in enumerate(rects):
    left=rect.rect.left() #x1
    top=rect.rect.top() #y1
    right=rect.rect.right() #x2
    bottom=rect.rect.bottom() #y2
  width=right-left
  height=bottom-top
  img_crop=img[top:top+height,left:left+width]
  img_path=path+'/Test_Images_crop/'+file_name.split('/')[-1].split('_')[0]+'/'+file_name.split('/')[-1]
  cv2.imwrite(img_path,img_crop)

# %% [markdown]
# Face Extraction using DLIB

# %%
# Load the face detection package [USE GPU]
# !wget http://dlib.net/files/mmod_human_face_detector.dat.bz2 
# !bzip2 -dk mmod_human_face_detector.dat.bz2
dnnFaceDetector=dlib.cnn_face_detection_model_v1("/mntDrive/My Drive/Face_Recognition/mmod_human_face_detector.dat")
# Out:
# --2020-08-26 05:27:52--  http://dlib.net/files/mmod_human_face_detector.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 694709 (678K)
# Saving to: ‘mmod_human_face_detector.dat.bz2.3’
#
# mmod_human_face_det 100%[===================>] 678.43K   539KB/s    in 1.3s
#
# 2020-08-26 05:27:53 (539 KB/s) - ‘mmod_human_face_detector.dat.bz2.3’ saved [694709/694709]
#
# bzip2: Output file mmod_human_face_detector.dat already exists.

# %%
os.mkdir(path+'/Images_crop/')

# %%
# For each person create a separate folder
for person in person_names:
  os.mkdir(path+'/Images_crop/'+person+'/')

# %%
# Detect face, crop detected face and save them in corresponding person folder
for file_name in image_path_names:
  img=cv2.imread(file_name)
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  rects=dnnFaceDetector(gray,1)
  left,top,right,bottom=0,0,0,0
  for (i,rect) in enumerate(rects):
    left=rect.rect.left() #x1
    top=rect.rect.top() #y1
    right=rect.rect.right() #x2
    bottom=rect.rect.bottom() #y2
  width=right-left
  height=bottom-top
  img_crop=img[top:top+height,left:left+width]
  img_path=path+'/Images_crop/'+file_name.split('/')[-1].split('_')[0]+'/'+file_name.split('/')[-1]
  cv2.imwrite(img_path,img_crop)

# %%
# Get Image names for testing
test_image_path_names=[]
for file_name in glob.glob(path+'/Images_test/*_[1-9].png'):
  test_image_path_names.append(file_name)

# %% [markdown]
# Face Classifier

# %%
# !gdown  https://drive.google.com/ucid=1CPSeum3HpopfomUEK1gybeuIVoeJT_Eo
# Out:
# /usr/local/lib/python2.7/dist-packages/gdown/parse_url.py:31: UserWarning: You specified Google Drive Link but it is not the correct link to download the file. Maybe you should try: https://drive.google.com/uc?id=None
#   .format(url='https://drive.google.com/uc?id={}'.format(file_id))
# Downloading...
# From: https://drive.google.com/ucid=1CPSeum3HpopfomUEK1gybeuIVoeJT_Eo
# To: /content/ucid=1CPSeum3HpopfomUEK1gybeuIVoeJT_Eo
# 100% 83.5k/83.5k [00:00<00:00, 30.8MB/s]

# %%
#Define VGG_FACE_MODEL architecture
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Convolution2D(4096, (7, 7), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# %%
# Load VGG Face model weights
model.load_weights('/mntDrive/My Drive/Face_Recognition/vgg_face_weights.h5')

# %%
vgg_face=Model(inputs=model.layers[0].input,outputs=model.layers[-2].output)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 226, 226, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 114, 114, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 114, 114, 128)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 58, 58, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 4096)        102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 1, 1, 2622)        10742334
# _________________________________________________________________
# flatten (Flatten)            (None, 2622)              0
# _________________________________________________________________
# activation (Activation)      (None, 2622)              0
# =================================================================
# Total params: 145,002,878
# Trainable params: 145,002,878
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Prepare Training Data
x_train=[]
y_train=[]
person_folders=os.listdir(path+'/Images_crop/')
person_rep=dict()
for i,person in enumerate(person_folders):
  person_rep[i]=person
  image_names=os.listdir(path+'/Images_crop/'+person+'/')
  for image_name in image_names:
    img=load_img(path+'/Images_crop/'+person+'/'+image_name,target_size=(224,224))
    img=img_to_array(img)
    img=np.expand_dims(img,axis=0)
    img=preprocess_input(img)
    img_encode=vgg_face(img)
    x_train.append(np.squeeze(K.eval(img_encode)).tolist())
    y_train.append(i)

# %%
person_rep
# Out:
# {0: 'kasthuri', 1: 'puja', 2: 'aravindh'}

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)

# %%
#Prepare Test Data
x_test=[]
y_test=[]
person_folders=os.listdir(path+'/Test_Images_crop/')
for i,person in enumerate(person_folders):
  image_names=os.listdir(path+'/Test_Images_crop/'+person+'/')
  for image_name in image_names:
    img=load_img(path+'/Test_Images_crop/'+person+'/'+image_name,target_size=(224,224))
    img=img_to_array(img)
    img=np.expand_dims(img,axis=0)
    img=preprocess_input(img)
    img_encode=vgg_face(img)
    x_test.append(np.squeeze(K.eval(img_encode)).tolist())
    y_test.append(i)

# %%
# Save test and train data for later use
np.save('train_data',x_train)
np.save('train_labels',y_train)
np.save('test_data',x_test)
np.save('test_labels',y_test)

# %%
# Load saved data
x_train=np.load('train_data.npy')
y_train=np.load('train_labels.npy')
x_test=np.load('test_data.npy')
y_test=np.load('test_labels.npy')

# %%
# Softmax regressor to classify images based on encoding 
classifier_model=Sequential()
classifier_model.add(Dense(units=100,input_dim=x_train.shape[1],kernel_initializer='glorot_uniform'))
classifier_model.add(BatchNormalization())
classifier_model.add(Activation('tanh'))
classifier_model.add(Dropout(0.3))
classifier_model.add(Dense(units=10,kernel_initializer='glorot_uniform'))
classifier_model.add(BatchNormalization())
classifier_model.add(Activation('tanh'))
classifier_model.add(Dropout(0.2))
classifier_model.add(Dense(units=6,kernel_initializer='he_uniform'))
classifier_model.add(Activation('softmax'))
classifier_model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),optimizer='nadam',metrics=['accuracy'])

# %%
classifier_model.fit(x_train,y_train,epochs=100,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 243ms/step - loss: 1.7156 - accuracy: 0.3333 - val_loss: 1.5021 - val_accuracy: 0.2500
# Epoch 2/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0207 - accuracy: 0.5000 - val_loss: 1.2813 - val_accuracy: 0.3750
# Epoch 3/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9667 - accuracy: 0.6667 - val_loss: 1.2429 - val_accuracy: 0.3750
# Epoch 4/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9112 - accuracy: 0.6667 - val_loss: 1.0339 - val_accuracy: 0.6250
# Epoch 5/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6644 - accuracy: 0.8333 - val_loss: 0.9307 - val_accuracy: 0.7500
# Epoch 6/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.7546 - accuracy: 0.8333 - val_loss: 0.8883 - val_accuracy: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6360 - accuracy: 0.8333 - val_loss: 0.8449 - val_accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6788 - accuracy: 0.6667 - val_loss: 0.7820 - val_accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6338 - accuracy: 1.0000 - val_loss: 0.7608 - val_accuracy: 0.7500
# Epoch 10/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5810 - accuracy: 1.0000 - val_loss: 0.7338 - val_accuracy: 0.7500
# Epoch 11/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5529 - accuracy: 1.0000 - val_loss: 0.7144 - val_accuracy: 0.7500
# Epoch 12/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6525 - accuracy: 1.0000 - val_loss: 0.7000 - val_accuracy: 0.7500
# Epoch 13/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5808 - accuracy: 1.0000 - val_loss: 0.6789 - val_accuracy: 0.7500
# Epoch 14/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5557 - accuracy: 1.0000 - val_loss: 0.6726 - val_accuracy: 0.7500
# Epoch 15/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8307 - accuracy: 0.8333 - val_loss: 0.6498 - val_accuracy: 0.8750
# Epoch 16/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5904 - accuracy: 1.0000 - val_loss: 0.6393 - val_accuracy: 0.8750
# Epoch 17/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6207 - accuracy: 1.0000 - val_loss: 0.6283 - val_accuracy: 0.8750
# Epoch 18/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5089 - accuracy: 1.0000 - val_loss: 0.6250 - val_accuracy: 0.8750
# Epoch 19/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6533 - accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.8750
# Epoch 20/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7014 - accuracy: 0.8333 - val_loss: 0.6145 - val_accuracy: 0.8750
# Epoch 21/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5649 - accuracy: 1.0000 - val_loss: 0.6042 - val_accuracy: 0.8750
# Epoch 22/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5592 - accuracy: 1.0000 - val_loss: 0.6029 - val_accuracy: 0.8750
# Epoch 23/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5871 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8750
# Epoch 24/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5062 - accuracy: 1.0000 - val_loss: 0.5853 - val_accuracy: 0.8750
# Epoch 25/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5054 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.8750
# Epoch 26/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.7852 - accuracy: 0.8333 - val_loss: 0.5733 - val_accuracy: 0.8750
# Epoch 27/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6434 - accuracy: 1.0000 - val_loss: 0.5754 - val_accuracy: 0.8750
# Epoch 28/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6512 - accuracy: 0.8333 - val_loss: 0.5808 - val_accuracy: 0.8750
# Epoch 29/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5072 - accuracy: 1.0000 - val_loss: 0.5746 - val_accuracy: 0.8750
# Epoch 30/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6155 - accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.8750
# Epoch 31/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6961 - accuracy: 1.0000 - val_loss: 0.5772 - val_accuracy: 0.8750
# Epoch 32/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5699 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 0.8750
# Epoch 33/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5009 - accuracy: 1.0000 - val_loss: 0.5611 - val_accuracy: 0.8750
# Epoch 34/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4643 - accuracy: 1.0000 - val_loss: 0.5591 - val_accuracy: 0.8750
# Epoch 35/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5745 - accuracy: 0.8333 - val_loss: 0.5578 - val_accuracy: 0.8750
# Epoch 36/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6268 - accuracy: 1.0000 - val_loss: 0.5520 - val_accuracy: 0.8750
# Epoch 37/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5400 - accuracy: 1.0000 - val_loss: 0.5396 - val_accuracy: 0.8750
# Epoch 38/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7123 - accuracy: 1.0000 - val_loss: 0.5338 - val_accuracy: 0.8750
# Epoch 39/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5152 - accuracy: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.8750
# Epoch 40/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4022 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.8750
# Epoch 41/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6385 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3494 - accuracy: 1.0000 - val_loss: 0.4986 - val_accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4941 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4587 - accuracy: 1.0000 - val_loss: 0.4848 - val_accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5422 - accuracy: 1.0000 - val_loss: 0.4799 - val_accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3909 - accuracy: 1.0000 - val_loss: 0.4824 - val_accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6018 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7351 - accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4383 - accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4734 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6060 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4003 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6241 - accuracy: 0.8333 - val_loss: 0.4813 - val_accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5257 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4319 - accuracy: 1.0000 - val_loss: 0.4694 - val_accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4576 - accuracy: 1.0000 - val_loss: 0.4622 - val_accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4984 - accuracy: 1.0000 - val_loss: 0.4635 - val_accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5465 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4318 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4462 - accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5121 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3446 - accuracy: 1.0000 - val_loss: 0.4525 - val_accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3561 - accuracy: 1.0000 - val_loss: 0.4462 - val_accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3860 - accuracy: 1.0000 - val_loss: 0.4456 - val_accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3540 - accuracy: 1.0000 - val_loss: 0.4450 - val_accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4746 - accuracy: 1.0000 - val_loss: 0.4386 - val_accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4773 - accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4729 - accuracy: 1.0000 - val_loss: 0.4357 - val_accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4290 - accuracy: 1.0000 - val_loss: 0.4336 - val_accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5096 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4781 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4283 - accuracy: 1.0000 - val_loss: 0.4264 - val_accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4866 - accuracy: 0.8333 - val_loss: 0.4239 - val_accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3984 - accuracy: 1.0000 - val_loss: 0.4318 - val_accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4186 - accuracy: 1.0000 - val_loss: 0.4282 - val_accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4887 - accuracy: 1.0000 - val_loss: 0.4275 - val_accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4911 - accuracy: 0.8333 - val_loss: 0.4205 - val_accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4589 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3365 - accuracy: 1.0000 - val_loss: 0.4178 - val_accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3839 - accuracy: 1.0000 - val_loss: 0.4196 - val_accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4545 - accuracy: 1.0000 - val_loss: 0.4223 - val_accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3010 - accuracy: 1.0000 - val_loss: 0.4203 - val_accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3548 - accuracy: 1.0000 - val_loss: 0.4227 - val_accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3430 - accuracy: 1.0000 - val_loss: 0.4135 - val_accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3466 - accuracy: 1.0000 - val_loss: 0.4097 - val_accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3209 - accuracy: 1.0000 - val_loss: 0.4098 - val_accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3675 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5128 - accuracy: 0.8333 - val_loss: 0.4169 - val_accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4302 - accuracy: 1.0000 - val_loss: 0.4185 - val_accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3220 - accuracy: 1.0000 - val_loss: 0.4088 - val_accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3129 - accuracy: 1.0000 - val_loss: 0.4043 - val_accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3429 - accuracy: 1.0000 - val_loss: 0.4010 - val_accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3926 - accuracy: 1.0000 - val_loss: 0.3975 - val_accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3734 - accuracy: 1.0000 - val_loss: 0.3994 - val_accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5786 - accuracy: 0.8333 - val_loss: 0.4087 - val_accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3178 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3022 - accuracy: 1.0000 - val_loss: 0.4077 - val_accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3756 - accuracy: 1.0000 - val_loss: 0.4013 - val_accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3708 - accuracy: 1.0000 - val_loss: 0.3961 - val_accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3227 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 1.0000

# %%
# Save model for later use
tf.keras.models.save_model(classifier_model,'/mntDrive/My Drive/Face_Recognition/aravy_face_classifier.h5')

# %%
# Load saved model
classifier_model=tf.keras.models.load_model('/mntDrive/My Drive/Face_Recognition/aravy_face_classifier.h5')

# %%
test_images_path=path+'/Images_Val/'
dnnFaceDetector=dlib.cnn_face_detection_model_v1("mmod_human_face_detector.dat")

# %%
def plot(img):
  plt.figure(figsize=(8,4))
  plt.imshow(img[:,:,::-1])
  plt.show()

# %%
os.mkdir(path+'/Predictions')

# %%
for img_name in os.listdir(path+'/Images_Val/'):
  if img_name=='crop_img.jpg':
    continue
  # Load Image
  img=cv2.imread(path+'/Images_Val/'+img_name)
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Detect Faces
  rects=dnnFaceDetector(gray,1)
  left,top,right,bottom=0,0,0,0
  for (i,rect) in enumerate(rects):
    # Extract Each Face
    left=rect.rect.left() #x1
    top=rect.rect.top() #y1
    right=rect.rect.right() #x2
    bottom=rect.rect.bottom() #y2
    width=right-left
    height=bottom-top
    img_crop=img[top:top+height,left:left+width]
    cv2.imwrite(path+'/Images_Val/crop_img.jpg',img_crop)
    
    # Get Embeddings
    crop_img=load_img(path+'/Images_Val/crop_img.jpg',target_size=(224,224))
    crop_img=img_to_array(crop_img)
    crop_img=np.expand_dims(crop_img,axis=0)
    crop_img=preprocess_input(crop_img)
    img_encode=vgg_face(crop_img)

    # Make Predictions
    embed=K.eval(img_encode)
    person=classifier_model.predict(embed)
    name=person_rep[np.argmax(person)]
    os.remove(path+'/Images_Val/crop_img.jpg')
    cv2.rectangle(img,(left,top),(right,bottom),(0,255,0), 2)
    img=cv2.putText(img,name,(left,top-10),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,255),2,cv2.LINE_AA)
    img=cv2.putText(img,str(np.max(person)),(right,bottom+10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),1,cv2.LINE_AA)
  # Save images with bounding box,name and accuracy 
  cv2.imwrite(path+'/Predictions/'+img_name,img)
  plot(img)
